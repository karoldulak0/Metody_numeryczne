# %% [markdown]
# # <center>Laboratorium 6<br>Metod Numerycznych</center>

# %% [markdown]
# Instrukcja:
# Na zajęciach należy wykonać poniższe zadania, dokonać testu na platformie github, a następnie sporządzić sprawozdanie zawierające odpowiedzi z komentarzami.

# %%
import main

import numpy as np
import scipy
import matplotlib
import matplotlib.pyplot as plt

# %%
#skopiowane funkcje z zadania domowego 

f1 = lambda x : np.sign(x)*x + x**2
f2 = lambda x: np.sign(x)*x**2
f3 = lambda x: (np.abs(np.sin(5*x)))**3
f4_1 = lambda x: 1/(1+x**2)
f4_2 = lambda x: 1/(1+25*(x**2))
f4_3 = lambda x: 1/(1+100*(x**2))
f5 = lambda x: np.sign(x) 

interpolation_quality = []

# %% [markdown]
# ***Zadanie 1.***
#
# Zaimlementować wzór barycentryczny podany na wykładzie jako funkcję barycentric_inte w main.py. Następnie dla funkcji ciągłej nieróżniczkowalnej z [Zadania domoego 2] przeprowadzić interpolację metodą  [barycentryczną](https://people.maths.ox.ac.uk/trefethen/barycentric.pdf) zarówno przy użyciu funkcji *[barycentric_interpolate](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.interpolate.barycentric_interpolate.html)* z pakietu *[Scipy](https://scipy.org/)* jak i za zaimplementowanego wzoru barycentrycznego. W tym celu należy:
#
#  - Wykonać w węzłach Czebyszewa (zaimplementowanych w ramach zadania domowego) interpolację rzędu 10, 100, 1000, 10000, 100000.
#  - Wykreślić wykresy obrazujące wyniki interpolacji (wykres oryginalnej funkcji i funkcji interpolującej w 1000 punktów).
#  - Przeanalizować czas obliczeń w zależności od rzędu interpolacji.

# %% [markdown]
# Przykład użycia funkcji barycentric_interpolate:

# %%
#from scipy.interpolate import barycentric_interpolate

# funkcja do interpolacji
#f = lambda x: np.cos(x)+x**2

# wektor współrzędnych x dla których chcemy wyliczyć wartości wielomianu interpolacyjnego
#x = np.linspace(-1,1,1000)

# węzły Czebyszewa 
#interpolation_nodes_number = 1e1
#xch = np.cos(np.linspace(1,interpolation_nodes_number,interpolation_nodes_number)*np.pi/interpolation_nodes_number)

# interpoalcja metodą barycentryczną
#yimp = barycentric_interpolate(xch,f(xch),x)

#plt.plot(x,f(x),'b',  linewidth=3 ,label = 'cos(x)+x**2')
#plt.plot(x,yimp,'r',label = 'interpolacja')
#plt.plot(xch,f(xch),'go',label = 'węzły interpolacji')
#plt.xlabel("x")
#plt.ylabel("y")
#plt.legend(loc = 0)
#plt.grid()
#plt.show()

#Interpolacja – wielopunktowe przybliżenie krzywizny toru ruchu.

# %%
#wykres funkcji ciągłej nieróżniczkowalnej
x = np.linspace(-0.99, 0.99, 1000)
y = f1(x)
plt.plot(x,y)
plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.title(" Wykres funkcji f(x) = sgn(x)x + x^2")
plt.show()

# %%
#interpolacja 10 
from scipy.interpolate import barycentric_interpolate

# funkcja do interpolacji
#f1

# wektor współrzędnych x dla których chcemy wyliczyć wartości wielomianu interpolacyjnego
x = np.linspace(-0.99,0.99,1000)

# węzły Czebyszewa 
node = main.bar_czeb_weights(10)

x_node = main.chebyshev_nodes(10)

y_node = f1(x_node)

# wielomian interpolacyjny 
yimp = main.barycentric_inte(x_node,y_node,node,x)


plt.plot(x, yimp, label = 'f(x) = sgn(x)x + x^2')
plt.scatter(x_node, y_node, s=5, c="r", label = 'interpolacja')
plt.grid()
plt.legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolacja rzedu 10")
plt.show()

time1 = %timeit -r 5 -n 10 -o main.barycentric_inte(x_node,y_node,node,x)
t1= time1.average

interpolation_quality.append(main.L_inf(y, yimp))
# Out:
# 5.89 ms ± 995 µs per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %%
#interpolacja 100 
from scipy.interpolate import barycentric_interpolate

# funkcja do interpolacji
#f1

# wektor współrzędnych x dla których chcemy wyliczyć wartości wielomianu interpolacyjnego
x = np.linspace(-0.99,0.99,1000)

# węzły Czebyszewa 
node = main.bar_czeb_weights(100)
x_node = main.chebyshev_nodes(100)
y_node = f1(x_node)
# wielomian interpolacyjny 
yimp = main.barycentric_inte(x_node,y_node,node,x)

plt.plot(x, yimp, label = 'f(x) = sgn(x)x + x^2')
plt.scatter(x_node, y_node, s=5, c="r", label = 'interpolacja')
plt.grid()
plt.legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolacja rzedu 100")
plt.show()

time1 = %timeit -r 5 -n 10 -o main.barycentric_inte(x_node,y_node,node,x)
t2= time1.average

interpolation_quality.append(main.L_inf(y, yimp))
# Out:
# 12.5 ms ± 972 µs per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %%
#interpolacja 1000
from scipy.interpolate import barycentric_interpolate

# funkcja do interpolacji
#f1

# wektor współrzędnych x dla których chcemy wyliczyć wartości wielomianu interpolacyjnego
x = np.linspace(-0.99,0.99,1000)

# węzły Czebyszewa 
node = main.bar_czeb_weights(1000)
x_node = main.chebyshev_nodes(1000)
y_node = f1(x_node)
# wielomian interpolacyjny 
yimp = main.barycentric_inte(x_node,y_node,node,x)

plt.plot(x, yimp, label = 'f(x) = sgn(x)x + x^2')
plt.scatter(x_node, y_node, s=5, c="r", label = 'interpolacja')
plt.grid()
plt.legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolacja rzedu 1000")
plt.show()

time1 = %timeit -r 5 -n 10 -o main.barycentric_inte(x_node,y_node,node,x)
t3= time1.average

interpolation_quality.append(main.L_inf(y, yimp))
# Out:
# 85.3 ms ± 3.99 ms per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %%
#interpolacja 10000 
from scipy.interpolate import barycentric_interpolate

# funkcja do interpolacji
#f1

# wektor współrzędnych x dla których chcemy wyliczyć wartości wielomianu interpolacyjnego
x = np.linspace(-0.99,0.99,1000)

# węzły Czebyszewa 
node = main.bar_czeb_weights(10000)
x_node = main.chebyshev_nodes(10000)
y_node = f1(x_node)
# wielomian interpolacyjny 
yimp = main.barycentric_inte(x_node,y_node,node,x)

plt.plot(x, yimp, label = 'f(x) = sgn(x)x + x^2')
plt.scatter(x_node, y_node, s=5, c="r", label = 'interpolacja')
plt.grid()
plt.legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolacja rzedu 10000")
plt.show()

time1 = %timeit -r 5 -n 10 -o main.barycentric_inte(x_node,y_node,node,x)
t4= time1.average

interpolation_quality.append(main.L_inf(y, yimp))
# Out:
# 1.29 s ± 30.6 ms per loop (mean ± std. dev. of 5 runs, 10 loops each)

# %%
#interpolacja 100000 
from scipy.interpolate import barycentric_interpolate

# funkcja do interpolacji
#f1

# wektor współrzędnych x dla których chcemy wyliczyć wartości wielomianu interpolacyjnego
x = np.linspace(-0.99,0.99,1000)

# węzły Czebyszewa 
node = main.bar_czeb_weights(100000)
x_node = main.chebyshev_nodes(100000)
y_node = f1(x_node)
# wielomian interpolacyjny 
yimp = main.barycentric_inte(x_node,y_node,node,x)

plt.plot(x, yimp, label = 'f(x) = sgn(x)x + x^2')
plt.scatter(x_node, y_node, s=5, c="r", label = 'interpolacja')
plt.grid()
plt.legend
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolacja rzedu 100000")
plt.show()

time1 = %timeit -r 2 -n 2 -o main.barycentric_inte(x_node,y_node,node,x)
t5= time1.average

interpolation_quality.append(main.L_inf(y, yimp))
# Out:
# 9.85 s ± 413 ms per loop (mean ± std. dev. of 2 runs, 2 loops each)

# %%
p = [10 , 100 ,1000 , 10000, 100000]
t = [t1 , t2 , t3 , t4 ,t5]
plt.scatter(p, t, label ='czas')
plt.xlabel('ilosc n')
plt.ylabel('Czas')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()

# %%
print(interpolation_quality)

p = [10 , 100 ,1000 , 10000, 100000]
plt.scatter(p, interpolation_quality, label ='bład')
plt.xlabel('ilosc n')
plt.ylabel('wielkość błędu')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# [0.05921959662241706, 0.005967541390643418, 0.0005721637697344861, 7.07507484317858e-06, 1.5690119937431142e-07]

# %% [markdown]
# ***Zadanie 2.***
# Dla funkcji jednokrotnie i trzykrotnie różniczkowalnej z [Zadania domowego 2]. Przeanalizować w pętli jakość interpolacji dla różnych rzędów interpolacji $n$.
#
# W tym celu należy:
# - wyliczyć wartość funkcji i wielomianu interpolacyjnego w 1000 punktów (nie będącymi węzłami interpolacji np. punkty równoodległe),
# - wyliczyć normę różnicy tych wektorów (normę błędu) dla każdego badanego rzędu, maksymalny rząd należy przyjąć gdy błąd będzie na poziomie zera maszynowego.
# - dla każdej z funkcji sporządzić wykres w skali podwójnie logarytmicznej (obie osie), w którym oś argumentów to rząd interpolacji a oś wartości to odpowiadająca mu norma błędu,
# - dla porównania umieścić na wykresie dodatkowo wykres $n^{-v}$, gdzie $v$ to rząd najwyższej pochodnej funkcji (zobacz wykład).

# %%
# dla funckji np.sign(x)*x**2


x = np.linspace(-0.99, 0.99, 1000)
y = f2(x)
int_quality = []
int_list = [10, 100 , 1000]
bound = []
v = 2.102e4

for n in int_list:
    n0de = main.bar_czeb_weights(n)
    x_n = main.chebyshev_nodes(n)
    y_n = f2(x_n)
    yimp_n = main.barycentric_inte(x_n,y_n,n0de,x)
    int_quality.append(main.L_inf(y,yimp_n))
    bound.append(4 * v / 3 / np.pi / (n - 3)**3)

plt.plot(x, y, linewidth = 5, c = "r")
plt.plot(x, yimp_n, linewidth = 2, c = "b")
plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolacja np.sign(x)*x**2 rzedu 1000")

plt.show()

plt.plot(int_list, bound, linewidth = 2, c = "r")
plt.scatter(int_list, int_quality)
plt.grid()
plt.xlabel("rzad")
plt.ylabel("norma bledu")
plt.xscale("log")
plt.yscale("log")
plt.title("Zależność błędu od przybliżenia")
plt.show()

# %%
# dla funkcji |sin(5x)|^3


x = np.linspace(-0.99, 0.99, 1000)
y = f3(x)
int_quality = []
int_list = [10, 100 , 1000]
bound = []
v = 2.102e4

for n in int_list:
    n0de = main.bar_czeb_weights(n)
    x_n = main.chebyshev_nodes(n)
    y_n = f3(x_n)
    yimp_n = main.barycentric_inte(x_n,y_n,n0de,x)
    int_quality.append(main.L_inf(y,yimp_n))
    bound.append(4 * v / 3 / np.pi / (n - 3)**3)

plt.plot(x, y, linewidth = 5, c = "r")
plt.plot(x, yimp_n, linewidth = 2, c = "b")
plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.title("Interpolacja funkcji np.sign(x)*x**2 rzedu 1000")
plt.show()

plt.plot(int_list, bound, linewidth = 2, c = "r")
plt.scatter(int_list, int_quality)
plt.grid()
plt.xlabel("rzad")
plt.ylabel("norma bledu")
plt.xscale("log")
plt.yscale("log")
plt.title("Zależność błędu od przybliżenia")
plt.show()

# %% [markdown]
# ***Zadanie 3.***
# Dla funkcji nieciągłej z [Zadania domowego 2] przeanalizować efekt Gibbsa
# oddzielnie dla parzystych i nieparzystych $n$. Oddzielnie wyliczyć jaki jest minimalny błąd niezależny od rzędu. Dlaczego wartości dla parzystych i nieparzystych $n$ się różnią?
# ***Wskazówka:*** Wykonać wykres funkcji i jej funkcji interpolującej.

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#10 

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)
err = []

node10 = main.bar_czeb_weights(10)
x_node10 = main.chebyshev_nodes(10)
y_node10 = f5(x_node10)
yimp10 = main.barycentric_inte(x_node10, y_node10, node10, x)
plt.plot(x, y, "b")
plt.plot(x, yimp10, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 10")
err.append(main.L_inf(y,yimp10))
print(err)
# Out:
# [1.9955845641395353]

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#11 

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)

node11 = main.bar_czeb_weights(11)
x_node11 = main.chebyshev_nodes(11)
y_node11 = f5(x_node11)
yimp11 = main.barycentric_inte(x_node11, y_node11, node11, x)
plt.plot(x, y, "b")
plt.plot(x, yimp11, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 11")
err.append(main.L_inf(y,yimp11))
print(err)
# Out:
# [1.9955845641395353, 0.9918767363049772]

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#100 

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)
node100 = main.bar_czeb_weights(100)
x_node100 = main.chebyshev_nodes(100)
y_node100 = f5(x_node100)
yimp100 = main.barycentric_inte(x_node100, y_node100, node100, x)
plt.plot(x, y, "b")
plt.plot(x, yimp100, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 100")
err.append(main.L_inf(y,yimp100))
print(err)
# Out:
# [1.9955845641395353, 0.9918767363049772, 1.9546465060895837]

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#101 

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)
node101 = main.bar_czeb_weights(101)
x_node101 = main.chebyshev_nodes(101)
y_node101 = f5(x_node101)
yimp101 = main.barycentric_inte(x_node101, y_node101, node101, x)
plt.plot(x, y, "b")
plt.plot(x, yimp101, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 101")
err.append(main.L_inf(y,yimp101))
print(err)
# Out:
# [1.9955845641395353, 0.9918767363049772, 1.9546465060895837, 0.9257309295009121]

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#1000

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)
node1000 = main.bar_czeb_weights(1000)
x_node1000 = main.chebyshev_nodes(1000)
y_node1000 = f5(x_node1000)
yimp1000 = main.barycentric_inte(x_node1000, y_node1000, node1000, x)
plt.plot(x, y, "b")
plt.plot(x, yimp1000, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 1000")
err.append(main.L_inf(y,yimp1000))
print(err)
# Out:
# [1.9955845641395353, 0.9918767363049772, 1.9546465060895837, 0.9257309295009121, 1.4215394239995887]

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#1001

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)
node1001 = main.bar_czeb_weights(1001)
x_node1001 = main.chebyshev_nodes(1001)
y_node1001 = f5(x_node1001)
yimp1001 = main.barycentric_inte(x_node1001, y_node1001, node1001, x)
plt.plot(x, y, "b")
plt.plot(x, yimp1001, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 1001")
err.append(main.L_inf(y,yimp1001))
print(err)
# Out:
# [1.9955845641395353, 0.9918767363049772, 1.9546465060895837, 0.9257309295009121, 1.4215394239995887, 0.30736049793170916]

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#10000

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)
node10000 = main.bar_czeb_weights(10000)
x_node10000 = main.chebyshev_nodes(10000)
y_node10000 = f5(x_node10000)
yimp10000 = main.barycentric_inte(x_node10000, y_node10000, node10000, x)
plt.plot(x, y, "b")
plt.plot(x, yimp10000, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 10000")
err.append(main.L_inf(y,yimp10000))
print(err)
# Out:
# [1.9955845641395353, 0.9918767363049772, 1.9546465060895837, 0.9257309295009121, 1.4215394239995887, 0.30736049793170916, 0.05419595603671157]

# %%
# f5 = np.sign(x)
#funkcja nieciągła - efekt Gibbsa 
#10001

x = np.linspace(-0.99, 0.99, 1000)
y = f5(x)
node10001 = main.bar_czeb_weights(10001)
x_node10001 = main.chebyshev_nodes(10001)
y_node10001 = f5(x_node10001)
yimp10001 = main.barycentric_inte(x_node10001, y_node10001, node10001, x)
plt.plot(x, y, "b")
plt.plot(x, yimp10001, "r")
plt.grid()
plt.title("Efekt Gibbsa dla n = 10001")
err.append(main.L_inf(y,yimp10001))
print(err)
# Out:
# [1.9955845641395353, 0.9918767363049772, 1.9546465060895837, 0.9257309295009121, 1.4215394239995887, 0.30736049793170916, 0.05419595603671157, 0.08719200895496049]

# %%
print(err)
p = [10, 11, 100 ,101 , 1000, 1001, 10000,10001]

plt.scatter(p,err,label='bład')
plt.xlabel('rzad')
plt.ylabel('wartosc')
plt.xscale('log')
plt.yscale('log')
plt.legend
plt.grid()
plt.title('Blad dla efektu Gibssa')
# Out:
# [1.9955845641395353, 0.9918767363049772, 1.9546465060895837, 0.9257309295009121, 1.4215394239995887, 0.30736049793170916, 0.05419595603671157, 0.08719200895496049]
# Text(0.5, 1.0, 'Blad dla efektu Gibssa')

# %% [markdown]
# Materiały uzupełniające:
# - [Scipy Lecture Notes](http://www.scipy-lectures.org/index.html)
# - [NumPy for Matlab users](https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html#numpy-for-matlab-users)
# - [Python Tutorial - W3Schools](https://www.w3schools.com/python/default.asp)
# - [NumPy](https://www.numpy.org)
# - [Matplotlib](https://matplotlib.org/)
# - [Anaconda](https://www.anaconda.com/)
# - [Learn Python for Data Science](https://www.datacamp.com/learn-python-with-anaconda?utm_source=Anaconda_download&utm_campaign=datacamp_training&utm_medium=banner)
# - [Learn Python](https://www.learnpython.org/)
# - [Wujek Google](https://google.pl) i [Ciocia Wikipedia](https://pl.wikipedia.org/wiki/Wikipedia:Strona_g%C5%82%C3%B3wna)
